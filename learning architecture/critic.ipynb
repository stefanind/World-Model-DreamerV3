# %% [markdown]
# Critic:
#
# Goal is to evaluate the expected rewards given the model state (s_t). It does this by estimating the expected cumulative discounted reward that the agent will receive from that point onward, if it continues to follow the current policy.
# Issue: can't know the future rewards, only the next state. So

# %%
# visualizing how gamma impacts the expected rewards 
# a high gamma (weighs future rewards more) vs a low gamma (weighs future rewards less)
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0,100) # time steps
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
ax[0].plot(t, 0.997**t)
ax[1].plot(t, 0.9**t)

# %% [markdown]
# When discount factor is higher, future rewards are valued more because the decay
